# %% [markdown]
# # Lab 12: Data Analysis. Part 1
# ## vg-stats dataset ( including vgsales dataset )
# ## Date : 31/8/2020
# ## Osama Yousef

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %% [markdown]
# # Which company is the most common video game publisher?

# %%
df = pd.read_csv('vgsales.csv')
publisher_max = df['Publisher'].value_counts().idxmax()
publisher_max
# Out:
# 'Electronic Arts'

# %% [markdown]
# # What’s the most common platform?

# %%
df = pd.read_csv('vgsales.csv')
platform_max = df['Platform'].value_counts().idxmax()

platform_max
# Out:
# 'DS'

# %% [markdown]
# # What about the most common genre?

# %%
df = pd.read_csv('vgsales.csv')
genre_max = df['Genre'].value_counts().idxmax()

genre_max
# Out:
# 'Action'

# %% [markdown]
# # What are the top 20 highest grossing games?

# %%
df = pd.read_csv('vgsales.csv')
top_twenty = df.sort_values(by='Global_Sales', ascending=False).head(20)
top_twenty
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %% [markdown]
# # For North American video game sales, what’s the median?

# %%
df = pd.read_csv('vgsales.csv')
median_na_sales = df['NA_Sales'].median()
median_na_sales
# Out:
# 0.08

# %% [markdown]
# ## Provide a secondary output showing ten games surrounding the median sales output

# %%
around_median = df[df['NA_Sales'] == median_na_sales].head(10)
around_median
# Out:
#       Rank                                               Name Platform  \
# 446    447                                  Dragon Warrior IV      NES
# 497    498        World Soccer Winning Eleven 7 International      PS2
# 1617  1619                             Farming Simulator 2015       PC
# 1926  1928                          Pro Evolution Soccer 2008     X360
# 2067  2069  Winning Eleven: Pro Evolution Soccer 2007 (All...     X360
# 2373  2375                           Phantasy Star Portable 2      PSP
# 2579  2581                               The Sims 2: Castaway      PSP
# 3186  3188                                     SingStar Queen      PS2
# 3503  3505                                         Top Spin 3      PS3
# 3703  3705               Sonic & All-Stars Racing Transformed      PS3
#
#         Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# 446   1990.0  Role-Playing              Enix Corporation      0.08      0.00
# ...

# %% [markdown]
# ### For the top-selling game of all time, how many standard deviations above/below the mean are its sales for North America?

# %%
df = pd.read_csv('vgsales.csv')

sorted_by_top_game = df.sort_values('Global_Sales', ascending=False)

# %%
sorted_by_top_game[:1]
# Out:
#    Rank        Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo     41.49     29.02
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74

# %% [markdown]
# ### how many standard deviations above/below the mean are its sales for North America?

# %%
mean_sales = np.mean(sorted_by_top_game)

# %%
mean_sales = mean_sales['Global_Sales']

# %%
mean_sales
# Out:
# 0.5374406555006628

# %%
deviation_sales = np.std(sorted_by_top_game)

# %%
deviation_sales = deviation_sales['Global_Sales']

# %%
deviation_sales
# Out:
# 1.5549810910296606

# %%
top_game_sales = sorted_by_top_game.loc[0]['Global_Sales']

# %%
top_game_sales
# Out:
# 82.74

# %%
result = ((top_game_sales - mean_sales) / deviation_sales)

# %%
result
# Out:
# 52.864025047447576

# %% [markdown]
# #### so there is about 52-53 standard deviations above the mean

# %% [markdown]
# ## The Nintendo Wii seems to have outdone itself with games. How does its average number of sales compare with all of the other platforms?

# %% [markdown]
# #### first solution

# %%
wii_games = df[df.Platform == 'Wii']
not_wii_games = df[df.Platform != 'Wii']
wii_game_average = wii_games.Global_Sales.mean()
not_wii_game_average = not_wii_games.Global_Sales.mean()
print('Wii avg: ' + str(wii_game_average))
print('Not-Wii avg: ' + str(not_wii_game_average))
# Out:
# Wii avg: 0.6994037735849057
# Not-Wii avg: 0.5233896418516336

# %% [markdown]
# #### wii average price compare to all game average price:

# %%
results = wii_game_average - not_wii_game_average

# %%
results
# Out:
# 0.17601413173327207

# %% [markdown]
# # 3 more questions from us

# %% [markdown]
# ## Top 20 Most Popular Sports Games

# %%
df = pd.read_csv('vgsales.csv')
sports_games = df[df['Genre'] == 'Sports']
sports_games.sort_values(by='Global_Sales', ascending=False)
sports_games[:20]
# Out:
#      Rank                                       Name Platform    Year   Genre  \
# 0       1                                 Wii Sports      Wii  2006.0  Sports
# 3       4                          Wii Sports Resort      Wii  2009.0  Sports
# 13     14                                    Wii Fit      Wii  2007.0  Sports
# 14     15                               Wii Fit Plus      Wii  2009.0  Sports
# 77     78                                    FIFA 16      PS4  2015.0  Sports
# 85     86         Mario & Sonic at the Olympic Games      Wii  2007.0  Sports
# 112   113                                    FIFA 14      PS3  2013.0  Sports
# 117   118                              Zumba Fitness      Wii  2010.0  Sports
# 121   122                                    FIFA 12      PS3  2011.0  Sports
# 124   125                                    FIFA 15      PS4  2014.0  Sports
# 139   140                              Kinect Sports     X360  2010.0  Sports
# ...

# %% [markdown]
# ## Most Popular Shooters games

# %%
df = pd.read_csv('vgsales.csv')
shooters = df[df['Genre'] == 'Shooter']
shooters.sort_values(by='Global_Sales', ascending=False)
shooters[:20]
# Out:
#     Rank                            Name Platform    Year    Genre  \
# 9     10                       Duck Hunt      NES  1984.0  Shooter
# 29    30  Call of Duty: Modern Warfare 3     X360  2011.0  Shooter
# 31    32         Call of Duty: Black Ops     X360  2010.0  Shooter
# 33    34       Call of Duty: Black Ops 3      PS4  2015.0  Shooter
# 34    35      Call of Duty: Black Ops II      PS3  2012.0  Shooter
# 35    36      Call of Duty: Black Ops II     X360  2012.0  Shooter
# 36    37  Call of Duty: Modern Warfare 2     X360  2009.0  Shooter
# 37    38  Call of Duty: Modern Warfare 3      PS3  2011.0  Shooter
# 40    41         Call of Duty: Black Ops      PS3  2010.0  Shooter
# 43    44                          Halo 3     X360  2007.0  Shooter
# 55    56  Call of Duty: Modern Warfare 2      PS3  2009.0  Shooter
# 61    62            Call of Duty: Ghosts     X360  2013.0  Shooter
# 62    63                     Halo: Reach     X360  2010.0  Shooter
# ...

# %% [markdown]
# ## How many games came out in 2010?

# %%
number = df[df['Year'].between(2010 , 2010)]
len(number)
# Out:
# 1259

# %% [markdown]
# ## What is the least played genre of video game?

# %%
df.sort_values('Genre', ascending = False).head(1)
# Out:
#         Rank        Name Platform    Year     Genre   Publisher  NA_Sales  \
# 11820  11822  Kessen III      PS2  2004.0  Strategy  Tecmo Koei      0.04
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 11820      0.03       0.0         0.01          0.07

# %%
def test():

    def assert_equal(actual,expected):
        assert actual == expected, f"Expected {expected} but got {actual}"

    assert_equal(publisher_max , 'Electronic Arts' )
    assert_equal(platform_max, 'DS')
    assert_equal(genre_max, 'Action')
    assert_equal(median_na_sales, 0.08 )
    assert_equal(results, 0.17601413173327207 )


    print("Success!!!")

test()
# Out:
# Success!!!
